# %%
import os, os.path
import numpy as np
from time import time
import pandas as pd
import math as m
import setup_runs as sr
import importlib
import matplotlib.pyplot as plt
import itertools
# Out:
# WARNING: gams executable '/usr/local/bin/gams' not found.

# %%
def compare_params(df_old, df_new, fields_merge, fields_data):
    
    dict_out = {}
    
    #get fields
    fields_dat_old = [x for x in fields_data if x in df_old.columns]
    fields_dat_new = [x for x in fields_data if x in df_new.columns]
    fields_dat_red = list(set(fields_dat_new) & set(fields_dat_old))
    fields_dat_red = [x for x in fields_data if x in fields_dat_red]

    #find fields that were dropped, if they exist
    fields_dat_compl_old = list(set(fields_data) - set(fields_dat_old))
    fields_dat_compl_new = list(set(fields_data) - set(fields_dat_new))
    
    if len(fields_dat_compl_old) > 0:
        #notify what fields were dropped
        fields_dat_compl_old.sort()
        sr.print_list_output(fields_dat_compl_old, "Dropping data fields from df_old")
        #add to output dictionary
        dict_out.update({"fields_dat_compl_old": fields_dat_compl_old})
        
    if len(fields_dat_compl_new) > 0:
        #notify what fields were dropped
        fields_dat_compl_new.sort()
        sr.print_list_output(fields_dat_compl_new, "Dropping data fields from df_new")
        #add to output dictionary
        dict_out.update({"fields_dat_compl_new": fields_dat_compl_new})
    
    #get intersection and order
    fm = list(set(df_old.columns) & set(df_new.columns) & set(fields_merge))
    fm = [x for x in fields_merge if x in fm]
    #notify of fields that are merged on
    sr.print_list_output(fm, "Merging on")
    
    #build dictionaries to rename
    dict_rnm_new = dict([[x, "newp_" + x] for x in fields_dat_new])
    dict_rnm_old = dict([[x, "oldp_" + x] for x in fields_dat_old])
    dict_out.update({"dict_rnm_new": dict_rnm_new, "dict_rnm_old": dict_rnm_old})
    #rename the data frames
    df_new = df_new[fm + fields_dat_new].rename(columns = dict_rnm_new)
    df_old = df_old[fm + fields_dat_old].rename(columns = dict_rnm_old)
    
    #merge
    df_comp = pd.merge(df_old, df_new, how = "inner", on = fm).sort_values(by = fm).reset_index(drop = True).fillna(0)
    dict_out.update({"df_comp": df_comp})

    #find parameters that were dropped, if they exist
    parameters_dat_compl_old = list(set(df_comp["parameter"]) - set(df_old["parameter"]))
    parameters_dat_compl_new = list(set(df_comp["parameter"]) - set(df_new["parameter"]))

    #notify
    if len(parameters_dat_compl_old) > 0:
        #notify what fields were dropped
        parameters_dat_compl_old.sort()
        sr.print_list_output(parameters_dat_compl_old, "The following parameters from df_old were not kept")
        #add to output dictionary
        dict_out.update({"parameters_dat_compl_old": parameters_dat_compl_old})

    if len(parameters_dat_compl_new) > 0:
        #notify what fields were dropped
        parameters_dat_compl_new.sort()
        sr.print_list_output(parameters_dat_compl_new, "The following parameters from df_new were not kept")
        #add to output dictionary
        dict_out.update({"parameters_dat_compl_new": parameters_dat_compl_new})

    #compare fields
    array_new = np.array(df_comp[[("newp_" + x) for x in fields_dat_red]])
    array_old = np.array(df_comp[[("oldp_" + x) for x in fields_dat_red]])
    array_diff = abs(array_new - array_old)

    params_diff = set({})
    #find differences
    for i in range(len(array_diff)):
        w = np.where(array_diff[i] > 0.0001)[0]
        if len(w) > 0:
            #get parameter
            param = df_comp["parameter"].iloc[i]
            #add to output set
            params_diff = params_diff | set({param})

    dict_out.update({"params_diff": params_diff})
    
    return dict_out

# %%
df_params = pd.read_csv(sr.fp_csv_parameter_ranges)#(os.path.join(sr.dir_ref, "archive", "parameter_ranges_20210201.csv"))
#df2 = pd.read_csv(sr.fp_csv_parameter_ranges.replace(".csv", "_design_id-1_20210213.csv"))#(os.path.join(sr.dir_ref, "archive", "parameter_ranges_20210201.csv"))

df_0 = df_params[df_params["strategy_id"] == 0][[x for x in df_params.columns if x != "strategy_id"]].copy()
df_1 = df_params[df_params["strategy_id"] == 1][[x for x in df_params.columns if x != "strategy_id"]].copy()

fields_merge = ["sector", "time_series_id", "parameter"]
fields_data = ["normalize_group", "trajgroup_no_vary_q", "parameter_constant_q", "min_2050", "max_2050"] + [str(x) for x in range(2015, 2051)]


dict_compare = compare_params(df_0, df_1, fields_merge, fields_data)
# Out:
# ##############################
# Merging on:
# 	sector
# 	time_series_id
# 	parameter
# ##############################

# %%
df_params[df_params["parameter"].isin(dict_compare["params_diff"])][["parameter", "sector"]].drop_duplicates().copy().reset_index(drop = True)#.to_csv("/Users/jsyme/Desktop/parameters_different_in_ndcp_unique_list.csv", index = None, encoding = "UTF-8")
# Out:
#                                             parameter                 sector
# 0                           manejo_holistico_de_gando  Analytica_agriculture
# 1                        medida_cambio_dieta_nacional  Analytica_agriculture
# 2                             medida_captura_c_suelos  Analytica_agriculture
# 3                                 medida_algas_pardas     Analytica_forestry
# 4                     medida_aumento_parques_reservas     Analytica_forestry
# 5                        medida_forestacion_aumentada     Analytica_forestry
# 6                             medida_manejo_aumentada     Analytica_forestry
# 7                              medida_pmr_menos_papel     Analytica_forestry
# 8                              nueva_cap_recuperacion         Analytica_ippu
# 9                                          fp_compost        Analytica_waste
# 10                          steel_intensity_reference    industry_and_mining
# 11             trajgroup_1-trajmin_copper_heat_diesel    industry_and_mining
# 12              trajgroup_1-trajmin_copper_heat_solar    industry_and_mining
# 13             trajgroup_1-trajmix_copper_heat_diesel    industry_and_mining
# 14              trajgroup_1-trajmix_copper_heat_solar    industry_and_mining
# 15             trajgroup_8-trajmax_steel_heat_biomass    industry_and_mining
# 16                trajgroup_8-trajmax_steel_heat_coal    industry_and_mining
# 17                trajgroup_8-trajmax_steel_heat_coke    industry_and_mining
# 18            trajgroup_8-trajmax_steel_heat_hydrogen    industry_and_mining
# 19                 trajmin_residential_retrofit_house            residential
# 20                 trajmix_residential_retrofit_house            residential
# 21  trajgroup_9-trajmax_transport_frac_aviation_hy...              transport
# 22  trajgroup_9-trajmax_transport_frac_aviation_ke...              transport
# 23  trajgroup_9-trajmix_transport_frac_aviation_hy...              transport
# 24  trajgroup_9-trajmix_transport_frac_aviation_ke...              transport
# 25               transport_modal_split_private_to_bus              transport
# 26           transport_modal_split_private_to_cycling              transport
# 27          transport_modal_split_private_to_telework              transport

# %%
fields_merge = ["sector", "time_series_id", "strategy_id", "parameter"]
fields_data = ["normalize_group", "trajgroup_no_vary_q", "parameter_constant_q", "min_2050", "max_2050"] + [str(x) for x in range(2015, 2051)]

df_params_old = pd.read_csv(sr.fp_csv_parameter_ranges.replace(".csv", "_design_id-1.csv"))#(os.path.join(sr.dir_ref, "archive", "parameter_ranges_20210201.csv"))
df_params_car_ndc = pd.read_csv(os.path.join(sr.dir_ref, "ndc_plus_to_integrate", "parameter_ranges_carlos_ndc+.csv"))

secs_anaytica = set([x for x in list(df_params_old["sector"]) if "Analytica" in x]) | set({"all"})
secs_carlos = set(df_params_old["sector"]) - secs_anaytica

#read in additional files
df_params_ag_ndc = pd.read_excel(os.path.join(sr.dir_model, "analytica", "agriculture", "parameter_ranges-Rev-NDC+Agriculture.xlsx"))
df_params_fo_ndc = pd.read_excel(os.path.join(sr.dir_model, "analytica", "forestry", "parameter_ranges_Rev-NDC+Forestry.xlsx"))
df_params_ipwa_ndc = pd.read_csv(os.path.join(sr.dir_ref, "20210119-parameter_ranges -WasteIPPU.csv"))


#initialize the new strategy
df_params_init_strat = df_params_old[df_params_old["strategy_id"] == 1].copy()
df_params_init_strat["strategy_id"] = df_params_init_strat["strategy_id"].replace({1: 2})
#build
#df_params_base = pd.concat([df_params_old, df_params_init_strat], axis = 0).reset_index(drop = True)
df_params_base = df_params_old

#sets of files to integrate
dict_new_params = {
    "carlos": df_params_car_ndc,
    "agriculture": df_params_ag_ndc[df_params_ag_ndc["sector"] == "Analytica_agriculture"],
    "forestry": df_params_fo_ndc[df_params_fo_ndc["sector"] == "Analytica_forestry"],
    "ippu": df_params_ipwa_ndc[df_params_ipwa_ndc["sector"] == "Analytica_ippu"],
    "waste": df_params_ipwa_ndc[df_params_ipwa_ndc["sector"] == "Analytica_waste"]
}


#initialize the base
df_params_out = df_params_base[df_params_base["sector"].isin(["Analytica_all", "all"])]
df_params_init_strat = df_params_out[df_params_out["strategy_id"] == 1].copy()
df_params_init_strat["strategy_id"] = df_params_init_strat["strategy_id"].replace({1: 2})
df_params_out = pd.concat([df_params_out, df_params_init_strat], axis = 0).reset_index(drop = True)
#initialize as an ouput
df_params_out = [df_params_out]

for sec in ["carlos"]:#, "agriculture", "forestry", "ippu", "waste"]:
    
    if sec != "carlos":
        sec_an = "Analytica_" + sec
        #
        df_base_an = df_params_base[df_params_base["sector"] == sec_an]
        df_new_an = dict_new_params[sec]
    else:
        df_base_an = df_params_base[df_params_base["sector"].isin(secs_carlos)]
        df_new_an = dict_new_params[sec][dict_new_params[sec]["sector"].isin(secs_carlos)]
    
    
    #columns to rename to string
    dict_rnm_base = dict([[x, str(x)] for x in df_base_an.columns if (type(x) == int) or x.isnumeric()])
    dict_rnm_new = dict([[x, str(x)] for x in df_new_an.columns if (type(x) == int) or x.isnumeric()])

    df_base_an = df_base_an.rename(columns = dict_rnm_base)
    df_new_an = df_new_an.rename(columns = dict_rnm_new)
    
    
    #strategies in both
    strat_both = set(df_base_an["strategy_id"]) & set(df_new_an["strategy_id"])
    #new strategies
    strat_comp_new = set(df_new_an["strategy_id"]) - strat_both
    #compare old, pre NDC+ strategies to new file to check for additional changes to parameters
    dict_compare = compare_params(df_base_an[df_base_an["strategy_id"].isin(strat_both)], df_new_an[df_new_an["strategy_id"].isin(strat_both)], fields_merge, fields_data)
    #get parameters that have changed
    change_params = dict_compare["params_diff"]
    #get new params
    params_new = set(df_new_an["parameter"]) - set(df_base_an["parameter"])
    
    
    #drop any parameters from the base
    df_base_an = df_base_an[~df_base_an["parameter"].isin(change_params)]
    #pull change params, new params, or additional data from 
    df_new_an = df_new_an[df_new_an["parameter"].isin(change_params) | df_new_an["parameter"].isin(params_new) | df_new_an["strategy_id"].isin(strat_comp_new)]
    
    fields_both = set(df_base_an.columns) & set(df_new_an.columns)
    #add any fields
    if set(df_base_an.columns) != set(df_new_an.columns):
        add_base = list(set(df_new_an.columns) - set(df_base_an.columns))
        add_new = list(set(df_base_an.columns) - set(df_new_an.columns))
        
        for field in add_base:
            df_base_an[field] = [np.nan for x in range(len(df_base_an))]
            
        for field in add_new:
            df_new_an[field] = [np.nan for x in range(len(df_new_an))]
    
    df_comp = pd.concat([df_base_an, df_new_an[list(df_base_an.columns)]], axis = 0, ignore_index = True)
    #add to the output
    df_params_out.append(df_comp)

df_params_out = pd.concat(df_params_out, axis = 0)   

#some parameters to replace
dict_preps = {
    "Manejo_Holistico_de_gando": "manejo_holistico_de_gando", 
    "Medida_Cambio_Dieta_Nacional": "medida_cambio_dieta_nacional",
    "fpCompost": "fp_compost"
}

df_params_out["parameter"] = df_params_out["parameter"].replace(dict_preps)
#update the strategies
df_params_out = df_params_out[df_params_out["strategy_id"] > 0].copy()
df_params_out["strategy_id"] = df_params_out["strategy_id"].replace({1:0})
df_params_out["strategy_id"] = df_params_out["strategy_id"].replace({2:1})

#fields to sort on
fields_sort = ["sector", "type", "parameter", "time_series_id", "strategy_id"]
df_params_out = df_params_out.sort_values(by = fields_sort).reset_index(drop = True)
# Out:
# ##############################
# Dropping data fields from df_new:
# 	trajgroup_no_vary_q
# ##############################
#
#
#
#
#
#
# ##############################
# Merging on:
# 	sector
# 	time_series_id
# 	strategy_id
# 	parameter
# ##############################

# %%
cp = list(change_params)

df_params_old = pd.read_csv(sr.fp_csv_parameter_ranges)
strs = ["trajmax", "trajmin", "trajmix"]

updates = []
for c in cp:
    for s in strs:
        comp = list(set(strs) - set({s}))
        if s in c:
            #strings to add in
            updates = updates + [c.replace(s, x) for x in comp]
updates = set(updates)
change_params = change_params | updates

fields_sort = ["sector", "parameter", "time_series_id", "strategy_id"]
df_out1 = dict_new_params["carlos"][dict_new_params["carlos"]["parameter"].isin(change_params)].reset_index(drop = True).sort_values(by = fields_sort)
df_out1["strategy_id"] = df_out1["strategy_id"].replace({1: 0})
df_out1["strategy_id"] = df_out1["strategy_id"].replace({2: 1})
df_out2 = df_params_old[~df_params_old["parameter"].isin(change_params)].reset_index(drop = True).sort_values(by = fields_sort)
df_out3 = df_params_old[df_params_old["parameter"].isin(change_params)].reset_index(drop = True).sort_values(by = fields_sort)

df_out1.to_csv(sr.fp_csv_parameter_ranges.replace(".csv", "_CARCOMP.csv"), index = None, encoding = "UTF-8")
df_out2.to_csv(sr.fp_csv_parameter_ranges.replace(".csv", "_D1-REV.csv"), index = None, encoding = "UTF-8")
df_out3.to_csv(sr.fp_csv_parameter_ranges.replace(".csv", "_D1-OLD.csv"), index = None, encoding = "UTF-8")

# %% [raw]
# #df_params_old[df_params_old["parameter"].isin(change_params)].reset_index(drop = True).sort_values(by = fields_sort)
# updates

# %%
for sec in list(df_params_out["sector"].unique()):
    
    print("SECTOR " + sec + "\n")
    dfo = df_params_out[(df_params_out["sector"] == sec) & (df_params_out["strategy_id"] > 0)]
    s = dfo.shape
    
    #get parameters
    print("Sec shape: ")
    print(s)
    print("")
    
    #get numbers of parameters
    p = set(dfo["parameter"])
    
    if len(p)*4 != s[0]:
        dfop = list(list(dfo["parameter"]))
        #get params that are undercounted
        list_print = [x for x in list(set(dfop)) if dfop.count(x) < 4]
        
        sr.print_list_output(list_print, "incomplete parameters in sector '" + sec + "'")
        
        
    print("\n\n")
# Out:
# SECTOR Analytica_all
#
# Sec shape:
# (32, 46)
#
#
#
#
# SECTOR all
#
# Sec shape:
# (8, 46)
#
#
#
#
# SECTOR commercial
#
# Sec shape:
# (308, 46)
#
#
#
#
# SECTOR electricity_generation
#
# Sec shape:
# (112, 46)
#
#
#
#
# SECTOR industry_and_mining
#
# Sec shape:
# (1760, 46)
#
#
#
#
# SECTOR public
#
# Sec shape:
# (44, 46)
#
#
#
#
# SECTOR residential
#
# Sec shape:
# (588, 46)
#
#
#
#
# SECTOR transport
#
# Sec shape:
# (404, 46)
#
#
#
#
# SECTOR Analytica_agriculture
#
# Sec shape:
# (48, 46)
#
#
#
#
# SECTOR Analytica_forestry
#
# Sec shape:
# (84, 46)
#
#
#
#
# SECTOR Analytica_ippu
#
# Sec shape:
# (28, 46)
#
#
#
#
# SECTOR Analytica_waste
#
# Sec shape:
# (68, 46)

# %%
ll = list(df_params_out["parameter"].unique())#[df_params_out["strategy_id"] != 0]
ll.sort()

rep = {
    "Manejo_Holistico_de_gando": "manejo_holistico_de_gando", 
    "Medida_Cambio_Dieta_Nacional": "medida_cambio_dieta_nacional",
    "fpCompost": "fp_compost"
}
sr.print_list_output(ll, "params")
# Out:
# ##############################
# params:
# 	cement_emission_fact_coal
# 	cement_emission_fact_diesel
# 	cement_emission_fact_kerosene
# 	cement_emission_fact_natural_gas
# 	cement_frac_biomass
# 	cement_frac_coal
# 	cement_frac_diesel
# 	cement_frac_electric
# 	cement_frac_hydrogen
# 	cement_frac_kerosene
# 	cement_frac_natural_gas
# 	cement_frac_solar
# 	cement_frac_thermal_solar
# 	cement_intensity
# 	cement_production
# 	commercial_acs_diesel
# 	commercial_acs_natural_gas
# 	commercial_acs_pliqgas
# 	commercial_activity_acs
# 	commercial_activity_heating
# 	commercial_activity_motive
# 	commercial_activity_other
# 	commercial_dem_acs
# 	commercial_dem_heating
# 	commercial_dem_motive
# 	commercial_dem_other
# 	commercial_efficiency_acs_diesel
# 	commercial_efficiency_acs_natural_gas
# 	commercial_efficiency_acs_pliqgas
# 	commercial_efficiency_heating_diesel
# 	commercial_efficiency_heating_electric
# 	commercial_efficiency_heating_natural_gas
# 	commercial_efficiency_heating_pliqgas
# 	commercial_efficiency_motive_electric
# 	commercial_efficiency_other_biomass
# 	commercial_efficiency_other_diesel
# 	commercial_efficiency_other_electric
# 	commercial_efficiency_other_gas
# 	commercial_efficiency_other_hydrogen
# 	commercial_efficiency_other_kerosene
# 	commercial_efficiency_other_natural_gas
# 	commercial_efficiency_other_pliqgas
# 	commercial_elasticity
# 	commercial_emission_fact_diesel
# 	commercial_emission_fact_kerosene
# 	commercial_emission_fact_natural_gas
# 	commercial_emission_fact_pliqgas
# 	commercial_frac_biomass
# 	commercial_frac_diesel
# 	commercial_frac_electric
# 	commercial_frac_hydrogen
# 	commercial_frac_kerosene
# 	commercial_frac_natural_gas
# 	commercial_frac_pliqgas
# 	commercial_frac_solar
# 	commercial_fuel_price_biomass
# 	commercial_fuel_price_diesel
# 	commercial_fuel_price_electric
# 	commercial_fuel_price_hydrogen
# 	commercial_fuel_price_kerosene
# 	commercial_fuel_price_natural_gas
# 	commercial_fuel_price_pliqgas
# 	commercial_fuel_price_solar
# 	commercial_heating_diesel
# 	commercial_heating_electric
# 	commercial_heating_natural_gas
# 	commercial_heating_pliqgas
# 	commercial_investment_cost_acs_diesel
# 	commercial_investment_cost_acs_natural_gas
# 	commercial_investment_cost_acs_pliqgas
# 	commercial_investment_cost_heating_diesel
# 	commercial_investment_cost_heating_electric
# 	commercial_investment_cost_heating_natural_gas
# 	commercial_investment_cost_heating_pliqgas
# 	commercial_investment_cost_motive_electric
# 	commercial_investment_cost_other_biomass
# 	commercial_investment_cost_other_diesel
# 	commercial_investment_cost_other_electric
# 	commercial_investment_cost_other_gas
# 	commercial_investment_cost_other_kerosene
# 	commercial_investment_cost_other_natural_gas
# 	commercial_investment_cost_other_pliqgas
# 	commercial_motive_electric
# 	commercial_other_biomass
# 	commercial_other_diesel
# 	commercial_other_electric
# 	commercial_other_gas
# 	commercial_other_hydrogen
# 	commercial_other_kerosene
# 	commercial_other_natural_gas
# 	commercial_other_pliqgas
# 	commercial_relation_usefull_energy
# 	copper_activitiy_subt_mine
# 	copper_activity_heat
# 	copper_activity_motor
# 	copper_activity_open_pit_mine
# 	copper_activity_other
# 	copper_activity_subt_mine
# 	copper_efficiency_heat_diesel
# 	copper_efficiency_heat_electricitiy
# 	copper_efficiency_heat_hydrogen
# 	copper_efficiency_heat_natural_gas
# 	copper_efficiency_heat_plqgas
# 	copper_efficiency_heat_solar
# 	copper_efficiency_motor_diesel
# 	copper_efficiency_motor_electricitiy
# 	copper_efficiency_motor_hydrogen
# 	copper_efficiency_open_pit_mine_diesel
# 	copper_efficiency_open_pit_mine_electricitiy
# 	copper_efficiency_open_pit_mine_hydrogen
# 	copper_efficiency_other_diesel
# 	copper_efficiency_other_electricity
# 	copper_efficiency_other_natural_gas
# 	copper_efficiency_subt_mine_diesel
# 	copper_efficiency_subt_mine_electricitiy
# 	copper_efficiency_subt_mine_hydrogen
# 	copper_emission_fact_diesel
# 	copper_emission_fact_fueloil
# 	copper_emission_fact_kerosene
# 	copper_emission_fact_natural_gas
# 	copper_emission_fact_pliqgas
# 	copper_heat_electricitiy
# 	copper_heat_hydrogen
# 	copper_heat_natural_gas
# 	copper_heat_plqgas
# 	copper_intensity_useful_energy
# 	copper_investment_cost_heat_diesel
# 	copper_investment_cost_heat_electricitiy
# 	copper_investment_cost_heat_hydrogen
# 	copper_investment_cost_heat_natural_gas
# 	copper_investment_cost_heat_plqgas
# 	copper_investment_cost_heat_solar
# 	copper_investment_cost_motor_diesel
# 	copper_investment_cost_motor_electricitiy
# 	copper_investment_cost_motor_hydrogen
# 	copper_investment_cost_open_pit_mine_diesel
# 	copper_investment_cost_open_pit_mine_electricitiy
# 	copper_investment_cost_open_pit_mine_hydrogen
# 	copper_investment_cost_subt_mine_diesel
# 	copper_investment_cost_subt_mine_electricitiy
# 	copper_investment_cost_subt_mine_hydrogen
# 	copper_motor_diesel
# 	copper_motor_electricitiy
# 	copper_motor_hydrogen
# 	copper_open_investment_cost_pit_mine_diesel
# 	copper_open_investment_cost_pit_mine_electricitiy
# 	copper_open_investment_cost_pit_mine_hydrogen
# 	copper_open_pit_mine_hydrogen
# 	copper_other_diesel
# 	copper_other_electricity
# 	copper_other_natural_gas
# 	copper_share_heat
# 	copper_share_motor
# 	copper_share_open_pit_mine
# 	copper_share_other
# 	copper_share_subt_mine
# 	copper_subt_mine_diesel
# 	copper_subt_mine_electricitiy
# 	copper_subt_mine_hydrogen
# 	cumplimiento_metas
# 	ef_captura
# 	elast_res_ind_pib
# 	electrolyzer_efficiency
# 	fishing_emission_fact_coal
# 	fishing_emission_fact_diesel
# 	fishing_emission_fact_natural_gas
# 	fishing_frac_biomass
# 	fishing_frac_coal
# 	fishing_frac_diesel
# 	fishing_frac_electric
# 	fishing_frac_hydrogen
# 	fishing_frac_natural_gas
# 	fishing_frac_solar
# 	fishing_frac_thermal_solar
# 	fishing_intensity
# 	fishing_production
# 	fp_compost
# 	gdp
# 	growth_rate_gdp
# 	hfcmma
# 	hydrology_exceedance_probability
# 	imp_clinker
# 	incertidumbre_demanda_productos_forestales
# 	incertidumbre_incendio_bn
# 	incertidumbre_incendio_plantaciones
# 	incertidumbre_perdida_de_bosque_nativo
# 	incertidumbre_rendimiento_bn
# 	incertidumbre_rendimiento_plantacion
# 	incertidumbre_var_demanda_legna
# 	industry_and_mining_fuel_price_biomass
# 	industry_and_mining_fuel_price_coal
# 	industry_and_mining_fuel_price_coke
# 	industry_and_mining_fuel_price_diesel
# 	industry_and_mining_fuel_price_electric
# 	industry_and_mining_fuel_price_fuel_oil
# 	industry_and_mining_fuel_price_hydrogen
# 	industry_and_mining_fuel_price_kerosene
# 	industry_and_mining_fuel_price_natural_gas
# 	industry_and_mining_fuel_price_pliqgas
# 	industry_and_mining_fuel_price_solar
# 	industry_and_mining_investment_cost_heat_biomass
# 	industry_and_mining_investment_cost_heat_coal
# 	industry_and_mining_investment_cost_heat_coke
# 	industry_and_mining_investment_cost_heat_diesel
# 	industry_and_mining_investment_cost_heat_electric
# 	industry_and_mining_investment_cost_heat_fuel_oil
# 	industry_and_mining_investment_cost_heat_hydrogen
# 	industry_and_mining_investment_cost_heat_natural_gas
# 	industry_and_mining_investment_cost_heat_pliqgas
# 	industry_and_mining_investment_cost_heat_solar
# 	industry_and_mining_investment_cost_motor_diesel
# 	industry_and_mining_investment_cost_motor_electric
# 	industry_and_mining_investment_cost_motor_hydrogen
# 	industry_and_mining_investment_cost_motor_pliqgas
# 	inv_antorcha
# 	inv_ptas
# 	iron_activity_heat
# 	iron_activity_motor
# 	iron_activity_other
# 	iron_efficiency_heat_biomass
# 	iron_efficiency_heat_coal
# 	iron_efficiency_heat_coke
# 	iron_efficiency_heat_diesel
# 	iron_efficiency_heat_electric
# 	iron_efficiency_heat_fuel_oil
# 	iron_efficiency_heat_hydrogen
# 	iron_efficiency_heat_natural_gas
# 	iron_efficiency_heat_pliqgas
# 	iron_efficiency_heat_solar
# 	iron_efficiency_motor_diesel
# 	iron_efficiency_motor_electric
# 	iron_efficiency_motor_hydrogen
# 	iron_efficiency_motor_pliqgas
# 	iron_efficiency_other_electric
# 	iron_emission_fact_coal
# 	iron_emission_fact_coke
# 	iron_emission_fact_diesel
# 	iron_emission_fact_fueloil
# 	iron_emission_fact_natural_gas
# 	iron_emission_fact_pliqgas
# 	iron_heat_biomass
# 	iron_heat_coal
# 	iron_heat_coke
# 	iron_heat_diesel
# 	iron_heat_electric
# 	iron_heat_fuel_oil
# 	iron_heat_hydrogen
# 	iron_heat_natural_gas
# 	iron_heat_pliqgas
# 	iron_heat_solar
# 	iron_intensity
# 	iron_intensity_reference
# 	iron_investment_efficiency_improvement
# 	iron_motor_diesel
# 	iron_motor_electric
# 	iron_motor_hydrogen
# 	iron_motor_pliqgas
# 	iron_other_electric
# 	iron_plant_factor_sst
# 	iron_production
# 	iron_share_heat
# 	iron_share_motor
# 	iron_share_other
# 	manejo_holistico_de_gando
# 	medida_algas_pardas
# 	medida_aumento_parques_reservas
# 	medida_biodigestores
# 	medida_cambio_dieta_bovina
# 	medida_cambio_dieta_nacional
# 	medida_captura_c_suelos
# 	medida_forestacion_aumentada
# 	medida_forestacion_bn
# 	medida_forestacion_plantaciones
# 	medida_incendio_bosque_nativo
# 	medida_incendio_plantaciones_forestales
# 	medida_manejo_aumentada
# 	medida_plan_de_manejo
# 	medida_pmr_menos_papel
# 	medida_sustitucion_degradacion
# 	medida_uso_eficiente_fertilizante
# 	nueva_cap_recuperacion
# 	other_industries_activity_heat
# 	other_industries_activity_motor
# 	other_industries_activity_other
# 	other_industries_efficiency_heat_biomass
# 	other_industries_efficiency_heat_coal
# 	other_industries_efficiency_heat_diesel
# 	other_industries_efficiency_heat_electric
# 	other_industries_efficiency_heat_fuel_oil
# 	other_industries_efficiency_heat_hydrogen
# 	other_industries_efficiency_heat_natural_gas
# 	other_industries_efficiency_heat_pliqgas
# 	other_industries_efficiency_heat_solar
# 	other_industries_efficiency_motor_diesel
# 	other_industries_efficiency_motor_electric
# 	other_industries_efficiency_motor_hydrogen
# 	other_industries_efficiency_motor_pliqgas
# 	other_industries_efficiency_other_electric
# 	other_industries_elasticity
# 	other_industries_emission_fact_coal
# 	other_industries_emission_fact_diesel
# 	other_industries_emission_fact_fueloil
# 	other_industries_emission_fact_natural_gas
# 	other_industries_emission_fact_pliqgas
# 	other_industries_frac_biomass
# 	other_industries_frac_coal
# 	other_industries_frac_diesel
# 	other_industries_frac_electric
# 	other_industries_frac_hydrogen
# 	other_industries_frac_natural_gas
# 	other_industries_frac_solar
# 	other_industries_frac_thermal_solar
# 	other_industries_heat_biomass
# 	other_industries_heat_electric
# 	other_industries_heat_hydrogen
# 	other_industries_intensity
# 	other_industries_motor_diesel
# 	other_industries_motor_electric
# 	other_industries_motor_hydrogen
# 	other_industries_motor_pliqgas
# 	other_industries_other_electric
# 	other_industries_rate_useful_energy
# 	other_industries_share_heat
# 	other_industries_share_motor
# 	other_industries_share_other
# 	other_mining_activity_heat
# 	other_mining_activity_motor
# 	other_mining_activity_other
# 	other_mining_efficiency_heat_biomass
# 	other_mining_efficiency_heat_coal
# 	other_mining_efficiency_heat_diesel
# 	other_mining_efficiency_heat_electric
# 	other_mining_efficiency_heat_fuel_oil
# 	other_mining_efficiency_heat_hydrogen
# 	other_mining_efficiency_heat_natural_gas
# 	other_mining_efficiency_heat_pliqgas
# 	other_mining_efficiency_heat_solar
# 	other_mining_efficiency_motor_diesel
# 	other_mining_efficiency_motor_electric
# 	other_mining_efficiency_motor_hydrogen
# 	other_mining_efficiency_motor_pliqgas
# 	other_mining_efficiency_other_electric
# 	other_mining_emission_fact_coal
# 	other_mining_emission_fact_diesel
# 	other_mining_emission_fact_fueloil
# 	other_mining_emission_fact_natural_gas
# 	other_mining_emission_fact_pliqgas
# 	other_mining_frac_biomass
# 	other_mining_frac_coal
# 	other_mining_frac_diesel
# 	other_mining_frac_electric
# 	other_mining_frac_hydrogen
# 	other_mining_frac_natural_gas
# 	other_mining_frac_solar
# 	other_mining_frac_thermal_solar
# 	other_mining_heat_biomass
# 	other_mining_heat_coal
# 	other_mining_heat_diesel
# 	other_mining_heat_electric
# 	other_mining_heat_fuel_oil
# 	other_mining_heat_hydrogen
# 	other_mining_heat_natural_gas
# 	other_mining_heat_pliqgas
# 	other_mining_heat_solar
# 	other_mining_intensity
# 	other_mining_motor_diesel
# 	other_mining_motor_electric
# 	other_mining_motor_hydrogen
# 	other_mining_motor_pliqgas
# 	other_mining_other_electric
# 	other_mining_plant_factor_sst
# 	other_mining_production
# 	other_mining_share_heat
# 	other_mining_share_motor
# 	other_mining_share_other
# 	poblacion_rural
# 	poblacion_urbana
# 	precio_bovino
# 	precio_cerdo
# 	precio_leche
# 	precio_maiz
# 	precio_pollo
# 	precio_soya
# 	ptas_antofa
# 	ptas_biobio
# 	ptas_valpo
# 	ptasls_coq
# 	public_emission_fact_kerosene
# 	public_emission_fact_natural_gas
# 	public_emission_fact_pliqgas
# 	public_frac_biomass
# 	public_frac_diesel
# 	public_frac_electric
# 	public_frac_kerosene
# 	public_frac_natural_gas
# 	public_frac_pliqgas
# 	public_frac_solar
# 	public_intensity
# 	pulp_activity_heat
# 	pulp_activity_motor
# 	pulp_activity_other
# 	pulp_efficiency_heat_biomass
# 	pulp_efficiency_heat_coal
# 	pulp_efficiency_heat_diesel
# 	pulp_efficiency_heat_electric
# 	pulp_efficiency_heat_fuel_oil
# 	pulp_efficiency_heat_hydrogen
# 	pulp_efficiency_heat_natural_gas
# 	pulp_efficiency_heat_pliqgas
# 	pulp_efficiency_heat_solar
# 	pulp_efficiency_motor_diesel
# 	pulp_efficiency_motor_electric
# 	pulp_efficiency_motor_hydrogen
# 	pulp_efficiency_motor_pliqgas
# 	pulp_efficiency_other_electric
# 	pulp_emission_fact_coal
# 	pulp_emission_fact_diesel
# 	pulp_emission_fact_fueloil
# 	pulp_emission_fact_natural_gas
# 	pulp_emission_fact_pliqgas
# 	pulp_frac_biomass
# 	pulp_frac_diesel
# 	pulp_frac_electric
# 	pulp_frac_hydrogen
# 	pulp_frac_natural_gas
# 	pulp_frac_solar
# 	pulp_frac_thermal_solar
# 	pulp_heat_biomass
# 	pulp_heat_coal
# 	pulp_heat_diesel
# 	pulp_heat_electric
# 	pulp_heat_fuel_oil
# 	pulp_heat_hydrogen
# 	pulp_heat_natural_gas
# 	pulp_heat_pliqgas
# 	pulp_heat_solar
# 	pulp_intensity
# 	pulp_motor_diesel
# 	pulp_motor_electric
# 	pulp_motor_hydrogen
# 	pulp_motor_pliqgas
# 	pulp_other_electric
# 	pulp_plant_factor_sst
# 	pulp_production
# 	pulp_share_heat
# 	pulp_share_motor
# 	pulp_share_other
# 	residential_activity_acs
# 	residential_activity_cooking
# 	residential_activity_electric_appliance
# 	residential_activity_heating
# 	residential_apartment_acs_biomass
# 	residential_apartment_acs_hydrogen
# 	residential_apartment_acs_kerosene
# 	residential_apartment_cooking_biomass
# 	residential_apartment_cooking_electric
# 	residential_apartment_cooking_hydrogen
# 	residential_apartment_cooking_kerosene
# 	residential_apartment_cooking_natural_gas
# 	residential_apartment_cooking_pliqgas
# 	residential_apartment_cooking_solar
# 	residential_apartment_heating_biomass
# 	residential_apartment_heating_electric
# 	residential_apartment_heating_hydrogen
# 	residential_apartment_heating_kerosene
# 	residential_apartment_heating_natural_gas
# 	residential_apartment_heating_pliqgas
# 	residential_apartment_heating_solar
# 	residential_apartment_intensity_acs
# 	residential_apartment_intensity_cooking
# 	residential_apartment_intensity_electric_appliance
# 	residential_apartment_intensity_heating
# 	residential_efficiency_acs_biomass
# 	residential_efficiency_acs_electric
# 	residential_efficiency_acs_hydrogen
# 	residential_efficiency_acs_kerosene
# 	residential_efficiency_acs_natural_gas
# 	residential_efficiency_acs_pliqgas
# 	residential_efficiency_acs_solar
# 	residential_efficiency_cooking_biomass
# 	residential_efficiency_cooking_electric
# 	residential_efficiency_cooking_hydrogen
# 	residential_efficiency_cooking_kerosene
# 	residential_efficiency_cooking_natural_gas
# 	residential_efficiency_cooking_pliqgas
# 	residential_efficiency_cooking_solar
# 	residential_efficiency_electric_appliance
# 	residential_efficiency_heating_biomass
# 	residential_efficiency_heating_electric
# 	residential_efficiency_heating_hydrogen
# 	residential_efficiency_heating_kerosene
# 	residential_efficiency_heating_natural_gas
# 	residential_efficiency_heating_pliqgas
# 	residential_efficiency_heating_solar
# 	residential_emission_fact_kerosene
# 	residential_emission_fact_natural_gas
# 	residential_emission_fact_pliqgas
# 	residential_frac_biomass
# 	residential_frac_electric
# 	residential_frac_hydrogen
# 	residential_frac_kerosene
# 	residential_frac_natural_gas
# 	residential_frac_pliqgas
# 	residential_frac_solar
# 	residential_fuel_price_biomass
# 	residential_fuel_price_electric
# 	residential_fuel_price_hydrogen
# 	residential_fuel_price_kerosene
# 	residential_fuel_price_natural_gas
# 	residential_fuel_price_pliqgas
# 	residential_fuel_price_solar
# 	residential_house_acs_biomass
# 	residential_house_acs_hydrogen
# 	residential_house_acs_kerosene
# 	residential_house_cooking_biomass
# 	residential_house_cooking_electric
# 	residential_house_cooking_hydrogen
# 	residential_house_cooking_kerosene
# 	residential_house_cooking_natural_gas
# 	residential_house_cooking_pliqgas
# 	residential_house_cooking_solar
# 	residential_house_heating_biomass
# 	residential_house_heating_electric
# 	residential_house_heating_hydrogen
# 	residential_house_heating_kerosene
# 	residential_house_heating_natural_gas
# 	residential_house_heating_pliqgas
# 	residential_house_heating_solar
# 	residential_house_intensity_acs
# 	residential_house_intensity_cooking
# 	residential_house_intensity_electric_appliance
# 	residential_house_intensity_heating
# 	residential_intensity
# 	residential_investment_cost_acs_biomass
# 	residential_investment_cost_acs_electric
# 	residential_investment_cost_acs_hydrogen
# 	residential_investment_cost_acs_kerosene
# 	residential_investment_cost_acs_natural_gas
# 	residential_investment_cost_acs_pliqgas
# 	residential_investment_cost_acs_solar
# 	residential_investment_cost_cooking_biomass
# 	residential_investment_cost_cooking_electric
# 	residential_investment_cost_cooking_hydrogen
# 	residential_investment_cost_cooking_kerosene
# 	residential_investment_cost_cooking_natural_gas
# 	residential_investment_cost_cooking_pliqgas
# 	residential_investment_cost_cooking_solar
# 	residential_investment_cost_electric_appliance
# 	residential_investment_cost_heating_biomass
# 	residential_investment_cost_heating_electric
# 	residential_investment_cost_heating_hydrogen
# 	residential_investment_cost_heating_kerosene
# 	residential_investment_cost_heating_natural_gas
# 	residential_investment_cost_heating_pliqgas
# 	residential_investment_cost_heating_solar
# 	residential_investment_cost_pv_solar
# 	residential_investment_cost_retrofit_apartment
# 	residential_investment_cost_retrofit_house
# 	residential_occ_rate
# 	residential_retrofit_apartment
# 	residential_retrofit_energy_reduction_apartment
# 	residential_retrofit_energy_reduction_house
# 	residential_retrofit_house
# 	residential_share_household_apartment
# 	residential_share_household_house
# 	rs_arauc
# 	rs_aysen
# 	rs_coq
# 	rs_magallanes
# 	rs_tarapaca
# 	rs_valpo
# 	saltpeter_emission_fact_coal
# 	saltpeter_emission_fact_diesel
# 	saltpeter_emission_fact_natural_gas
# 	saltpeter_frac_biomass
# 	saltpeter_frac_coal
# 	saltpeter_frac_diesel
# 	saltpeter_frac_electric
# 	saltpeter_frac_hydrogen
# 	saltpeter_frac_natural_gas
# 	saltpeter_frac_solar
# 	saltpeter_frac_thermal_solar
# 	saltpeter_intensity
# 	saltpeter_production
# 	share_electric_grid_to_hydrogen
# 	steel_activity_heat
# 	steel_activity_motor
# 	steel_activity_other
# 	steel_efficiency_heat_biomass
# 	steel_efficiency_heat_coal
# 	steel_efficiency_heat_coke
# 	steel_efficiency_heat_diesel
# 	steel_efficiency_heat_electric
# 	steel_efficiency_heat_fuel_oil
# 	steel_efficiency_heat_hydrogen
# 	steel_efficiency_heat_natural_gas
# 	steel_efficiency_heat_pliqgas
# 	steel_efficiency_heat_solar
# 	steel_efficiency_motor_diesel
# 	steel_efficiency_motor_electric
# 	steel_efficiency_motor_hydrogen
# 	steel_efficiency_motor_pliqgas
# 	steel_efficiency_other_electric
# 	steel_emission_fact_coal
# 	steel_emission_fact_coke
# 	steel_emission_fact_diesel
# 	steel_emission_fact_fueloil
# 	steel_emission_fact_natural_gas
# 	steel_emission_fact_pliqgas
# 	steel_heat_biomass
# 	steel_heat_coal
# 	steel_heat_coke
# 	steel_heat_diesel
# 	steel_heat_electric
# 	steel_heat_fuel_oil
# 	steel_heat_hydrogen
# 	steel_heat_natural_gas
# 	steel_heat_pliqgas
# 	steel_heat_solar
# 	steel_intensity
# 	steel_intensity_reference
# 	steel_investment_efficiency_improvement
# 	steel_motor_diesel
# 	steel_motor_electric
# 	steel_motor_hydrogen
# 	steel_motor_pliqgas
# 	steel_other_electric
# 	steel_plant_factor_sst
# 	steel_production
# 	steel_share_heat
# 	steel_share_motor
# 	steel_share_other
# 	sugar_emission_fact_coal
# 	sugar_emission_fact_diesel
# 	sugar_emission_fact_natural_gas
# 	sugar_frac_biomass
# 	sugar_frac_coal
# 	sugar_frac_diesel
# 	sugar_frac_electric
# 	sugar_frac_hydrogen
# 	sugar_frac_natural_gas
# 	sugar_frac_solar
# 	sugar_frac_thermal_solar
# 	sugar_intensity
# 	sugar_production
# 	supuestos_mma_ippu
# 	supuestos_mma_waste
# 	tasa_fuga
# 	tf_comercial
# 	tf_industrial
# 	trajgroup_1-lhs
# 	trajgroup_1-trajmax_copper_heat_diesel
# 	trajgroup_1-trajmax_copper_heat_solar
# 	trajgroup_1-trajmin_copper_heat_diesel
# 	trajgroup_1-trajmin_copper_heat_solar
# 	trajgroup_1-trajmix_copper_heat_diesel
# 	trajgroup_1-trajmix_copper_heat_solar
# 	trajgroup_2-lhs
# 	trajgroup_2-trajmax_copper_open_pit_mine_diesel
# 	trajgroup_2-trajmax_copper_open_pit_mine_electricitiy
# 	trajgroup_2-trajmin_copper_open_pit_mine_diesel
# 	trajgroup_2-trajmin_copper_open_pit_mine_electricitiy
# 	trajgroup_2-trajmix_copper_open_pit_mine_diesel
# 	trajgroup_2-trajmix_copper_open_pit_mine_electricitiy
# 	trajgroup_3-lhs
# 	trajgroup_3-trajmax_other_industries_heat_coal
# 	trajgroup_3-trajmax_other_industries_heat_diesel
# 	trajgroup_3-trajmax_other_industries_heat_fuel_oil
# 	trajgroup_3-trajmax_other_industries_heat_natural_gas
# 	trajgroup_3-trajmax_other_industries_heat_pliqgas
# 	trajgroup_3-trajmax_other_industries_heat_solar
# 	trajgroup_3-trajmin_other_industries_heat_coal
# 	trajgroup_3-trajmin_other_industries_heat_diesel
# 	trajgroup_3-trajmin_other_industries_heat_fuel_oil
# 	trajgroup_3-trajmin_other_industries_heat_natural_gas
# 	trajgroup_3-trajmin_other_industries_heat_pliqgas
# 	trajgroup_3-trajmin_other_industries_heat_solar
# 	trajgroup_3-trajmix_other_industries_heat_coal
# 	trajgroup_3-trajmix_other_industries_heat_diesel
# 	trajgroup_3-trajmix_other_industries_heat_fuel_oil
# 	trajgroup_3-trajmix_other_industries_heat_natural_gas
# 	trajgroup_3-trajmix_other_industries_heat_pliqgas
# 	trajgroup_3-trajmix_other_industries_heat_solar
# 	trajgroup_4-lhs
# 	trajgroup_4-trajmax_residential_apartment_acs_electric
# 	trajgroup_4-trajmax_residential_apartment_acs_natural_gas
# 	trajgroup_4-trajmax_residential_apartment_acs_pliqgas
# 	trajgroup_4-trajmax_residential_apartment_acs_solar
# 	trajgroup_4-trajmin_residential_apartment_acs_electric
# 	trajgroup_4-trajmin_residential_apartment_acs_natural_gas
# 	trajgroup_4-trajmin_residential_apartment_acs_pliqgas
# 	trajgroup_4-trajmin_residential_apartment_acs_solar
# 	trajgroup_4-trajmix_residential_apartment_acs_electric
# 	trajgroup_4-trajmix_residential_apartment_acs_natural_gas
# 	trajgroup_4-trajmix_residential_apartment_acs_pliqgas
# 	trajgroup_4-trajmix_residential_apartment_acs_solar
# 	trajgroup_5-lhs
# 	trajgroup_5-trajmax_residential_house_acs_electric
# 	trajgroup_5-trajmax_residential_house_acs_natural_gas
# 	trajgroup_5-trajmax_residential_house_acs_pliqgas
# 	trajgroup_5-trajmax_residential_house_acs_solar
# 	trajgroup_5-trajmin_residential_house_acs_electric
# 	trajgroup_5-trajmin_residential_house_acs_natural_gas
# 	trajgroup_5-trajmin_residential_house_acs_pliqgas
# 	trajgroup_5-trajmin_residential_house_acs_solar
# 	trajgroup_5-trajmix_residential_house_acs_electric
# 	trajgroup_5-trajmix_residential_house_acs_natural_gas
# 	trajgroup_5-trajmix_residential_house_acs_pliqgas
# 	trajgroup_5-trajmix_residential_house_acs_solar
# 	trajgroup_6-lhs
# 	trajgroup_6-trajmax_transport_frac_private_electric
# 	trajgroup_6-trajmax_transport_frac_private_gasoline
# 	trajgroup_6-trajmax_transport_frac_private_hyb
# 	trajgroup_6-trajmin_transport_frac_private_electric
# 	trajgroup_6-trajmin_transport_frac_private_gasoline
# 	trajgroup_6-trajmin_transport_frac_private_hyb
# 	trajgroup_6-trajmix_transport_frac_private_electric
# 	trajgroup_6-trajmix_transport_frac_private_gasoline
# 	trajgroup_6-trajmix_transport_frac_private_hyb
# 	trajgroup_7-lhs
# 	trajgroup_7-trajmax_transport_frac_truck_diesel
# 	trajgroup_7-trajmax_transport_frac_truck_hydrogen
# 	trajgroup_7-trajmin_transport_frac_truck_diesel
# 	trajgroup_7-trajmin_transport_frac_truck_hydrogen
# 	trajgroup_7-trajmix_transport_frac_truck_diesel
# 	trajgroup_7-trajmix_transport_frac_truck_hydrogen
# 	trajgroup_8-lhs
# 	trajgroup_8-trajmax_steel_heat_biomass
# 	trajgroup_8-trajmax_steel_heat_coal
# 	trajgroup_8-trajmax_steel_heat_coke
# 	trajgroup_8-trajmax_steel_heat_hydrogen
# 	trajgroup_8-trajmin_steel_heat_biomass
# 	trajgroup_8-trajmin_steel_heat_coal
# 	trajgroup_8-trajmin_steel_heat_coke
# 	trajgroup_8-trajmin_steel_heat_hydrogen
# 	trajgroup_8-trajmix_steel_heat_biomass
# 	trajgroup_8-trajmix_steel_heat_coal
# 	trajgroup_8-trajmix_steel_heat_coke
# 	trajgroup_8-trajmix_steel_heat_hydrogen
# 	trajgroup_9-lhs
# 	trajgroup_9-trajmax_transport_frac_aviation_hydrogen
# 	trajgroup_9-trajmax_transport_frac_aviation_kerosene
# 	trajgroup_9-trajmin_transport_frac_aviation_hydrogen
# 	trajgroup_9-trajmin_transport_frac_aviation_kerosene
# 	trajgroup_9-trajmix_transport_frac_aviation_hydrogen
# 	trajgroup_9-trajmix_transport_frac_aviation_kerosene
# 	trajmax_copper_production
# 	trajmax_fuel_price_coal
# 	trajmax_fuel_price_diesel
# 	trajmax_fuel_price_fuel_oil
# 	trajmax_fuel_price_natural_gas
# 	trajmax_incertidumbre_megaincendio
# 	trajmax_investment_cost_csp_solar
# 	trajmax_investment_cost_geothermal
# 	trajmax_investment_cost_natural_gas_cc
# 	trajmax_investment_cost_pv_solar
# 	trajmax_investment_cost_wind
# 	trajmax_iron_production
# 	trajmax_pib
# 	trajmax_poblacion
# 	trajmax_pulp_production
# 	trajmax_residential_retrofit_house
# 	trajmin_copper_production
# 	trajmin_fuel_price_coal
# 	trajmin_fuel_price_diesel
# 	trajmin_fuel_price_fuel_oil
# 	trajmin_fuel_price_natural_gas
# 	trajmin_incertidumbre_megaincendio
# 	trajmin_investment_cost_csp_solar
# 	trajmin_investment_cost_geothermal
# 	trajmin_investment_cost_natural_gas_cc
# 	trajmin_investment_cost_pv_solar
# 	trajmin_investment_cost_wind
# 	trajmin_iron_production
# 	trajmin_pib
# 	trajmin_poblacion
# 	trajmin_pulp_production
# 	trajmin_residential_retrofit_house
# 	trajmix_copper_production
# 	trajmix_fuel_price_coal
# 	trajmix_fuel_price_diesel
# 	trajmix_fuel_price_fuel_oil
# 	trajmix_fuel_price_natural_gas
# 	trajmix_incertidumbre_megaincendio
# 	trajmix_investment_cost_csp_solar
# 	trajmix_investment_cost_geothermal
# 	trajmix_investment_cost_natural_gas_cc
# 	trajmix_investment_cost_pv_solar
# 	trajmix_investment_cost_wind
# 	trajmix_iron_production
# 	trajmix_pib
# 	trajmix_poblacion
# 	trajmix_pulp_production
# 	trajmix_residential_retrofit_house
# 	transport_activity_bus
# 	transport_activity_private
# 	transport_activity_taxi
# 	transport_activity_truck
# 	transport_aviation_investment_cost_hydrogen
# 	transport_aviation_investment_cost_kerosene
# 	transport_bus_investment_cost_diesel
# 	transport_bus_investment_cost_electric
# 	transport_bus_veh_km
# 	transport_emission_fact_diesel
# 	transport_emission_fact_fueloil
# 	transport_emission_fact_gasoline
# 	transport_emission_fact_kerosene_aviation
# 	transport_frac_aviation_hydrogen
# 	transport_frac_aviation_kerosene
# 	transport_frac_bus_diesel
# 	transport_frac_bus_electric
# 	transport_frac_private_diesel
# 	transport_frac_taxi_electric
# 	transport_frac_taxi_gasoline
# 	transport_fuel_price_diesel
# 	transport_fuel_price_electric
# 	transport_fuel_price_gasoline
# 	transport_fuel_price_hydrogen
# 	transport_fuel_price_kerosene_aviation
# 	transport_intensity_aviation_hydrogen
# 	transport_intensity_aviation_kerosene
# 	transport_intensity_bus_diesel
# 	transport_intensity_bus_electric
# 	transport_intensity_maritime
# 	transport_intensity_pkm_train
# 	transport_intensity_private_diesel
# 	transport_intensity_private_electric
# 	transport_intensity_private_gasoline
# 	transport_intensity_private_hyb_electric
# 	transport_intensity_private_hyb_gasoline
# 	transport_intensity_taxi_electric
# 	transport_intensity_taxi_gasoline
# 	transport_intensity_train_electric
# 	transport_intensity_train_freight_diesel
# 	transport_intensity_truck_diesel
# 	transport_intensity_truck_hydrogen
# 	transport_investment_cost_modal_split_private_to_bus
# 	transport_investment_cost_modal_split_private_to_cycling
# 	transport_investment_cost_modal_split_private_to_telework
# 	transport_investment_cost_modal_split_private_to_train
# 	transport_load_average_freight_train
# 	transport_load_average_truck
# 	transport_maritime_frac_diesel
# 	transport_maritime_frac_fueloil
# 	transport_modal_split_private_to_bus
# 	transport_modal_split_private_to_cycling
# 	transport_modal_split_private_to_taxi
# 	transport_modal_split_private_to_telework
# 	transport_modal_split_private_to_train
# 	transport_modal_split_truck
# 	transport_modal_split_truck_to_train
# 	transport_occupancy_rate_bus
# 	transport_occupancy_rate_private
# 	transport_occupancy_rate_taxi
# 	transport_occupancy_rate_train
# 	transport_pkm_aviation
# 	transport_private_investment_cost_diesel
# 	transport_private_investment_cost_electric
# 	transport_private_investment_cost_gasoline
# 	transport_private_investment_cost_hyb
# 	transport_saturation_aviation
# 	transport_share_diesel_private
# 	transport_share_diesel_truck
# 	transport_tkm_freight_train
# 	transport_tkm_maritime
# 	transport_train13_pkm
# 	transport_train5_pkm
# 	transport_train8_pkm
# 	transport_trip_distance_private
# 	transport_truck_investment_cost_diesel
# 	transport_truck_investment_cost_hydrogen
# ##############################

# %% [raw]
# strategies_to_keep = set({1, 2})
#
# #initialize
#
# ###  INTEGRATE CARLOS'S CHANGES
#
# dict_check_carlos = compare_params(df_params_out[df_params_out["strategy_id"].isin(strategies_to_keep)], df_params_car_ndc[df_params_car_ndc["strategy_id"].isin(strategies_to_keep)], fields_merge, fields_data)
# p_diff_carlos = dict_check_carlos["params_diff"] & set()
# p_diff_carlos.sort()
#
#
# df_params_out = df_params_out[]

# %%
p_diff_carlos
# Out:
# ['incertidumbre_var_demanda_legna',
#  'industry_and_mining_fuel_price_coal',
#  'industry_and_mining_fuel_price_coke',
#  'industry_and_mining_fuel_price_diesel',
#  'industry_and_mining_fuel_price_electric',
#  'industry_and_mining_fuel_price_fuel_oil',
#  'industry_and_mining_fuel_price_hydrogen',
#  'industry_and_mining_fuel_price_natural_gas',
#  'industry_and_mining_fuel_price_pliqgas',
#  'iron_efficiency_heat_hydrogen',
#  'iron_efficiency_heat_solar',
#  'medida_biodigestores',
#  'medida_cambio_dieta_bovina',
#  'medida_captura_c_suelos',
#  'medida_uso_eficiente_fertilizante',
#  'other_industries_efficiency_heat_hydrogen',
#  'other_industries_efficiency_heat_solar',
#  'other_industries_efficiency_motor_diesel',
#  'other_industries_elasticity',
#  'other_industries_motor_diesel',
#  'other_industries_motor_electric',
#  'other_industries_motor_pliqgas',
#  'other_industries_rate_useful_energy',
#  'other_industries_share_heat',
#  'other_industries_share_motor',
#  'other_industries_share_other',
#  'other_mining_efficiency_heat_hydrogen',
#  'other_mining_efficiency_heat_solar',
#  'other_mining_efficiency_motor_diesel',
#  'other_mining_heat_biomass',
#  'other_mining_heat_coal',
#  'other_mining_intensity',
#  'other_mining_motor_diesel',
#  'other_mining_motor_electric',
#  'other_mining_motor_hydrogen',
#  'other_mining_motor_pliqgas',
#  'other_mining_share_heat',
#  'other_mining_share_motor',
#  'other_mining_share_other',
#  'ptas_antofa',
#  'ptas_biobio',
#  'ptas_valpo',
#  'ptasls_coq',
#  'pulp_efficiency_heat_hydrogen',
#  'pulp_efficiency_heat_solar',
#  'pulp_efficiency_motor_diesel',
#  'residential_efficiency_acs_hydrogen',
#  'residential_efficiency_acs_solar',
#  'residential_efficiency_cooking_hydrogen',
#  'residential_efficiency_cooking_solar',
#  'residential_efficiency_heating_hydrogen',
#  'residential_efficiency_heating_solar',
#  'rs_arauc',
#  'rs_aysen',
#  'rs_coq',
#  'rs_magallanes',
#  'rs_tarapaca',
#  'rs_valpo',
#  'share_electric_grid_to_hydrogen',
#  'steel_efficiency_heat_hydrogen',
#  'steel_efficiency_heat_solar',
#  'steel_intensity_reference',
#  'trajgroup_1-trajmin_copper_heat_diesel',
#  'trajgroup_1-trajmin_copper_heat_solar',
#  'trajgroup_1-trajmix_copper_heat_diesel',
#  'trajgroup_1-trajmix_copper_heat_solar',
#  'trajgroup_8-trajmax_steel_heat_biomass',
#  'trajgroup_8-trajmax_steel_heat_coal',
#  'trajgroup_8-trajmax_steel_heat_coke',
#  'trajgroup_8-trajmax_steel_heat_hydrogen',
#  'trajgroup_8-trajmix_steel_heat_biomass',
#  'trajgroup_8-trajmix_steel_heat_coal',
#  'trajgroup_8-trajmix_steel_heat_coke',
#  'trajgroup_8-trajmix_steel_heat_hydrogen',
#  'trajgroup_9-trajmax_transport_frac_aviation_hydrogen',
#  'trajgroup_9-trajmax_transport_frac_aviation_kerosene',
#  'trajgroup_9-trajmin_transport_frac_aviation_hydrogen',
#  'trajgroup_9-trajmix_transport_frac_aviation_hydrogen',
#  'trajgroup_9-trajmix_transport_frac_aviation_kerosene',
#  'trajmax_incertidumbre_megaincendio',
#  'trajmax_residential_retrofit_house',
#  'trajmin_incertidumbre_megaincendio',
#  'trajmin_pib',
#  'trajmin_residential_retrofit_house',
#  'trajmix_copper_production',
#  'trajmix_residential_retrofit_house',
#  'transport_aviation_investment_cost_hydrogen',
#  'transport_aviation_investment_cost_kerosene',
#  'transport_intensity_aviation_hydrogen',
#  'transport_modal_split_private_to_bus',
#  'transport_modal_split_private_to_cycling',
#  'transport_modal_split_private_to_telework']
